# %% [markdown]
# # scraping Youtube with Python

# %%
# import the requirement modules
import os
import sys
import subprocess
import platform

# %%
# !pip install pytube
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from pytube import YouTube

# %%
link="https://www.youtube.com/watch?v=LK2Rqfavqcw"
yt = YouTube(link)
